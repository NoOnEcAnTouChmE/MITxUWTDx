# 45  North America      US  Massachusetts  Boston     10    1  2018
# 46  North America      US  Massachusetts  Boston     11    1  2018
# 47  North America      US  Massachusetts  Boston     12    1  2018
# 48  North America      US  Massachusetts  Boston      1    1  2019
# 49  North America      US  Massachusetts  Boston      2    1  2019
# 50  North America      US  Massachusetts  Boston      3    1  2019
# 51  North America      US  Massachusetts  Boston      4    1  2019
# 52  North America      US  Massachusetts  Boston      5    1  2019
# 53  North America      US  Massachusetts  Boston      6    1  2019
# 54  North America      US  Massachusetts  Boston      7    1  2019
# 55  North America      US  Massachusetts  Boston      8    1  2019
# 56  North America      US  Massachusetts  Boston      9    1  2019
# 57  North America      US  Massachusetts  Boston     10    1  2019
# 58  North America      US  Massachusetts  Boston     11    1  2019
# 59  North America      US  Massachusetts  Boston     12    1  2019
#
#     AvgTemperature
# 0             26.1
# 1             19.3
# 2             23.0
# 3             39.0
# 4             45.4
# 5             48.2
# 6             69.5
# 7             78.7
# 8             75.6
# 9             57.7
# 10            52.9
# 11            37.7
# 12            39.1
# 13            49.5
# 14            41.6
# 15            63.1
# 16            48.2
# 17            68.8
# 18            75.5
# 19            70.6
# 20            74.4
# 21            56.9
# 22            42.4
# 23            50.2
# 24            40.0
# 25            32.2
# 26            52.8
# 27            35.2
# 28            46.9
# 29            66.5
# 30            76.1
# 31            74.4
# 32            62.3
# 33            54.7
# 34            48.3
# 35            46.3
# 36             5.6
# 37            34.7
# 38            47.5
# 39            47.9
# 40            51.5
# 41            70.4
# 42            82.4
# 43            74.7
# 44            68.2
# 45            61.6
# 46            57.9
# 47            38.7
# 48            47.2
# 49            16.0
# 50            29.4
# 51            42.3
# 52            50.6
# 53            60.0
# 54            71.0
# 55            79.5
# 56            68.5
# 57            62.2
# 58            62.2
# 59            28.6

# %% [markdown]
# ##Accessing Rows and Columns

# %%
df.loc[28]
# Out:
# Region            North America
# Country                      US
# State             Massachusetts
# City                     Boston
# Month                         5
# Day                           1
# Year                       2017
# AvgTemperature             46.9
# Name: 28, dtype: object

# %%
df.loc[51]
# Out:
# Region            North America
# Country                      US
# State             Massachusetts
# City                     Boston
# Month                         4
# Day                           1
# Year                       2019
# AvgTemperature             42.3
# Name: 51, dtype: object

# %%
df["AvgTemperature"]
# Out:
# 0     26.1
# 1     19.3
# 2     23.0
# 3     39.0
# 4     45.4
# 5     48.2
# 6     69.5
# 7     78.7
# 8     75.6
# 9     57.7
# 10    52.9
# 11    37.7
# 12    39.1
# 13    49.5
# 14    41.6
# 15    63.1
# 16    48.2
# 17    68.8
# 18    75.5
# 19    70.6
# 20    74.4
# 21    56.9
# 22    42.4
# 23    50.2
# 24    40.0
# 25    32.2
# 26    52.8
# 27    35.2
# 28    46.9
# 29    66.5
# 30    76.1
# 31    74.4
# 32    62.3
# 33    54.7
# 34    48.3
# 35    46.3
# 36     5.6
# 37    34.7
# 38    47.5
# 39    47.9
# 40    51.5
# 41    70.4
# 42    82.4
# 43    74.7
# 44    68.2
# 45    61.6
# 46    57.9
# 47    38.7
# 48    47.2
# 49    16.0
# 50    29.4
# 51    42.3
# 52    50.6
# 53    60.0
# 54    71.0
# 55    79.5
# 56    68.5
# 57    62.2
# 58    62.2
# 59    28.6
# Name: AvgTemperature, dtype: float64

# %%
df.loc[10:15]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# 13  North America      US  Massachusetts  Boston      2    1  2016
# 14  North America      US  Massachusetts  Boston      3    1  2016
# 15  North America      US  Massachusetts  Boston      4    1  2016
#
#     AvgTemperature
# 10            52.9
# 11            37.7
# 12            39.1
# 13            49.5
# 14            41.6
# 15            63.1

# %%
columns = ["Month", "AvgTemperature"]  
df[columns]
# Out:
#     Month  AvgTemperature
# 0       1            26.1
# 1       2            19.3
# 2       3            23.0
# 3       4            39.0
# 4       5            45.4
# 5       6            48.2
# 6       7            69.5
# 7       8            78.7
# 8       9            75.6
# 9      10            57.7
# 10     11            52.9
# 11     12            37.7
# 12      1            39.1
# 13      2            49.5
# 14      3            41.6
# 15      4            63.1
# 16      5            48.2
# 17      6            68.8
# 18      7            75.5
# 19      8            70.6
# 20      9            74.4
# 21     10            56.9
# 22     11            42.4
# 23     12            50.2
# 24      1            40.0
# 25      2            32.2
# 26      3            52.8
# 27      4            35.2
# 28      5            46.9
# 29      6            66.5
# 30      7            76.1
# 31      8            74.4
# 32      9            62.3
# 33     10            54.7
# 34     11            48.3
# 35     12            46.3
# 36      1             5.6
# 37      2            34.7
# 38      3            47.5
# 39      4            47.9
# 40      5            51.5
# 41      6            70.4
# 42      7            82.4
# 43      8            74.7
# 44      9            68.2
# 45     10            61.6
# 46     11            57.9
# 47     12            38.7
# 48      1            47.2
# 49      2            16.0
# 50      3            29.4
# 51      4            42.3
# 52      5            50.6
# 53      6            60.0
# 54      7            71.0
# 55      8            79.5
# 56      9            68.5
# 57     10            62.2
# 58     11            62.2
# 59     12            28.6

# %%
df[["Month", "AvgTemperature"]]
# Out:
#     Month  AvgTemperature
# 0       1            26.1
# 1       2            19.3
# 2       3            23.0
# 3       4            39.0
# 4       5            45.4
# 5       6            48.2
# 6       7            69.5
# 7       8            78.7
# 8       9            75.6
# 9      10            57.7
# 10     11            52.9
# 11     12            37.7
# 12      1            39.1
# 13      2            49.5
# 14      3            41.6
# 15      4            63.1
# 16      5            48.2
# 17      6            68.8
# 18      7            75.5
# 19      8            70.6
# 20      9            74.4
# 21     10            56.9
# 22     11            42.4
# 23     12            50.2
# 24      1            40.0
# 25      2            32.2
# 26      3            52.8
# 27      4            35.2
# 28      5            46.9
# 29      6            66.5
# 30      7            76.1
# 31      8            74.4
# 32      9            62.3
# 33     10            54.7
# 34     11            48.3
# 35     12            46.3
# 36      1             5.6
# 37      2            34.7
# 38      3            47.5
# 39      4            47.9
# 40      5            51.5
# 41      6            70.4
# 42      7            82.4
# 43      8            74.7
# 44      9            68.2
# 45     10            61.6
# 46     11            57.9
# 47     12            38.7
# 48      1            47.2
# 49      2            16.0
# 50      3            29.4
# 51      4            42.3
# 52      5            50.6
# 53      6            60.0
# 54      7            71.0
# 55      8            79.5
# 56      9            68.5
# 57     10            62.2
# 58     11            62.2
# 59     12            28.6

# %%
df[["Month", "Year", "AvgTemperature"]]
# Out:
#     Month  Year  AvgTemperature
# 0       1  2015            26.1
# 1       2  2015            19.3
# 2       3  2015            23.0
# 3       4  2015            39.0
# 4       5  2015            45.4
# 5       6  2015            48.2
# 6       7  2015            69.5
# 7       8  2015            78.7
# 8       9  2015            75.6
# 9      10  2015            57.7
# 10     11  2015            52.9
# 11     12  2015            37.7
# 12      1  2016            39.1
# 13      2  2016            49.5
# 14      3  2016            41.6
# 15      4  2016            63.1
# 16      5  2016            48.2
# 17      6  2016            68.8
# 18      7  2016            75.5
# 19      8  2016            70.6
# 20      9  2016            74.4
# 21     10  2016            56.9
# 22     11  2016            42.4
# 23     12  2016            50.2
# 24      1  2017            40.0
# 25      2  2017            32.2
# 26      3  2017            52.8
# 27      4  2017            35.2
# 28      5  2017            46.9
# 29      6  2017            66.5
# 30      7  2017            76.1
# 31      8  2017            74.4
# 32      9  2017            62.3
# 33     10  2017            54.7
# 34     11  2017            48.3
# 35     12  2017            46.3
# 36      1  2018             5.6
# 37      2  2018            34.7
# 38      3  2018            47.5
# 39      4  2018            47.9
# 40      5  2018            51.5
# 41      6  2018            70.4
# 42      7  2018            82.4
# 43      8  2018            74.7
# 44      9  2018            68.2
# 45     10  2018            61.6
# 46     11  2018            57.9
# 47     12  2018            38.7
# 48      1  2019            47.2
# 49      2  2019            16.0
# 50      3  2019            29.4
# 51      4  2019            42.3
# 52      5  2019            50.6
# 53      6  2019            60.0
# 54      7  2019            71.0
# 55      8  2019            79.5
# 56      9  2019            68.5
# 57     10  2019            62.2
# 58     11  2019            62.2
# 59     12  2019            28.6

# %% [markdown]
# ##Sorting DataFrames

# %%
df_sorted = df.sort_values("AvgTemperature", ascending = False)  
df_sorted
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 42  North America      US  Massachusetts  Boston      7    1  2018
# 55  North America      US  Massachusetts  Boston      8    1  2019
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 30  North America      US  Massachusetts  Boston      7    1  2017
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 18  North America      US  Massachusetts  Boston      7    1  2016
# 43  North America      US  Massachusetts  Boston      8    1  2018
# 20  North America      US  Massachusetts  Boston      9    1  2016
# 31  North America      US  Massachusetts  Boston      8    1  2017
# 54  North America      US  Massachusetts  Boston      7    1  2019
# 19  North America      US  Massachusetts  Boston      8    1  2016
# 41  North America      US  Massachusetts  Boston      6    1  2018
# 6   North America      US  Massachusetts  Boston      7    1  2015
# 17  North America      US  Massachusetts  Boston      6    1  2016
# 56  North America      US  Massachusetts  Boston      9    1  2019
# 44  North America      US  Massachusetts  Boston      9    1  2018
# 29  North America      US  Massachusetts  Boston      6    1  2017
# 15  North America      US  Massachusetts  Boston      4    1  2016
# 32  North America      US  Massachusetts  Boston      9    1  2017
# 57  North America      US  Massachusetts  Boston     10    1  2019
# 58  North America      US  Massachusetts  Boston     11    1  2019
# 56  North America      US  Massachusetts  Boston      3    1  2015
# 57  North America      US  Massachusetts  Boston      2    1  2015
# 58  North America      US  Massachusetts  Boston      2    1  2019
# 59  North America      US  Massachusetts  Boston      1    1  2018
#
#     AvgTemperature
# 0             82.4
# 1             79.5
# 2             78.7
# 3             76.1
# 4             75.6
# 5             75.5
# 6             74.7
# 7             74.4
# 8             74.4
# 9             71.0
# 10            70.6
# 11            70.4
# 12            69.5
# 13            68.8
# 14            68.5
# 15            68.2
# 16            66.5
# 17            63.1
# 18            62.3
# 19            62.2
# 20            62.2
# 21            61.6
# 22            60.0
# 23            57.9
# 24            57.7
# 25            56.9
# 26            54.7
# 27            52.9
# 28            52.8
# 29            51.5
# 30            50.6
# 31            50.2
# 32            49.5
# 33            48.3
# 34            48.2
# 35            48.2
# 36            47.9
# 37            47.5
# 38            47.2
# 39            46.9
# 40            46.3
# 41            45.4
# 42            42.4
# 43            42.3
# 44            41.6
# 45            40.0
# 46            39.1
# 47            39.0
# 48            38.7
# 49            37.7
# 50            35.2
# 51            34.7
# 52            32.2
# 53            29.4
# 54            28.6
# 55            26.1
# 56            23.0
# 57            19.3
# 58            16.0
# 59             5.6

# %% [markdown]
# ##Running Built-in Functions on the Data

# %%
df["AvgTemperature"].mean()
# Out:
# 52.46166666666666

# %%
df["AvgTemperature"].max()
# Out:
# 82.4

# %%
df["AvgTemperature"].count()
# Out:
# 60

# %%
df['AvgTemperature'].min()
# Out:
# 5.6

# %% [markdown]
# ##Filtering Data

# %%
condition = df["AvgTemperature"] > 75  
condition
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55     True
# 56    False
# 57    False
# 58    False
# 59    False
# Name: AvgTemperature, dtype: bool

# %%
df.loc[condition]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 18  North America      US  Massachusetts  Boston      7    1  2016
# 30  North America      US  Massachusetts  Boston      7    1  2017
# 42  North America      US  Massachusetts  Boston      7    1  2018
# 55  North America      US  Massachusetts  Boston      8    1  2019
#
#     AvgTemperature
# 7             78.7
# 8             75.6
# 18            75.5
# 30            76.1
# 42            82.4
# 55            79.5

# %%
df.loc[(df["AvgTemperature"] > 75) & (df["Month"] == 8)]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 55  North America      US  Massachusetts  Boston      8    1  2019
#
#     AvgTemperature
# 7             78.7
# 55            79.5

# %%
df.loc[df["AvgTemperature"] < 50].count()
# Out:
# Region            28
# Country           28
# State             28
# City              28
# Month             28
# Day               28
# Year              28
# AvgTemperature    28
# dtype: int64

# %%
df.loc[df["Year"] == 2015].mean()
# Out:
# <ipython-input-163-88fc0977a4bf>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[df["Year"] == 2015].mean()
# Month                6.500000
# Day                  1.000000
# Year              2015.000000
# AvgTemperature      47.758333
# dtype: float64

# %% [markdown]
# ##Grouping Data

# %%
df.groupby("Year").mean()
# Out:
# <ipython-input-164-4c7a3ccb3838>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Year").mean()
#       Month  Day  AvgTemperature
# Year
# 2015    6.5  1.0       47.758333
# 2016    6.5  1.0       56.691667
# 2017    6.5  1.0       52.975000
# 2018    6.5  1.0       53.425000
# 2019    6.5  1.0       51.458333

# %%
df.groupby("Year").mean().loc[2017]
# Out:
# <ipython-input-165-762d32bf073d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Year").mean().loc[2017]
# Month              6.500
# Day                1.000
# AvgTemperature    52.975
# Name: 2017, dtype: float64

# %%
df.groupby("Year").mean()["AvgTemperature"]
# Out:
# <ipython-input-166-9315ae7599db>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Year").mean()["AvgTemperature"]
# Year
# 2015    47.758333
# 2016    56.691667
# 2017    52.975000
# 2018    53.425000
# 2019    51.458333
# Name: AvgTemperature, dtype: float64

# %%
allmaxtemps = df.groupby("Year").max()
allmaxtemps
# Out:
#              Region Country          State    City  Month  Day  AvgTemperature
# Year
# 2015  North America      US  Massachusetts  Boston     12    1            78.7
# 2016  North America      US  Massachusetts  Boston     12    1            75.5
# 2017  North America      US  Massachusetts  Boston     12    1            76.1
# 2018  North America      US  Massachusetts  Boston     12    1            82.4
# 2019  North America      US  Massachusetts  Boston     12    1            79.5

# %%
allmaxtemps.loc[2015]
# Out:
# Region            North America
# Country                      US
# State             Massachusetts
# City                     Boston
# Month                        12
# Day                           1
# AvgTemperature             78.7
# Name: 2015, dtype: object

# %%
temp2015 = allmaxtemps.loc[2015]["AvgTemperature"]  
temp2015
# Out:
# 78.7

# %%
condition = (df["AvgTemperature"] == temp2015)  
df.loc[condition]
# Out:
#           Region Country          State    City  Month  Day  Year  \
# 7  North America      US  Massachusetts  Boston      8    1  2015
#
#    AvgTemperature
# 7            78.7

# %% [markdown]
# ##Finding Correlations between Data Columns

# %%
df.corr()
# Out:
# <ipython-input-171-418f6c573bc7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        Month  Day          Year  AvgTemperature
# Month           1.000000e+00  NaN  2.168623e-14        0.452060
# Day                      NaN  NaN           NaN             NaN
# Year            2.168623e-14  NaN  1.000000e+00        0.033659
# AvgTemperature  4.520600e-01  NaN  3.365939e-02        1.000000

# %% [markdown]
# ## Visualizing Data
# ### x-y plot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["AvgTemperature"])

# %%
_= plt.plot(df["AvgTemperature"])

# %%
_= plt.plot(df["Month"], color="orange")

# %%
_= plt.plot(df["AvgTemperature"])
_= plt.plot(df["Month"])

# %%
_= plt.plot(df["AvgTemperature"])
_= plt.plot(df["Month"])
_= plt.plot(df['Year'])

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(len(df["AvgTemperature"])), df["AvgTemperature"])

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["AvgTemperature"], bins=10)
# Out:
# (array([ 1.,  2.,  3.,  4.,  8., 13.,  6.,  7., 10.,  6.]),
#  array([ 5.6 , 13.28, 20.96, 28.64, 36.32, 44.  , 51.68, 59.36, 67.04,
#         74.72, 82.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

# %%
c = df.corr()
c
# Out:
# <ipython-input-183-dbc179630a69>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c = df.corr()
#                        Month  Day          Year  AvgTemperature
# Month           1.000000e+00  NaN  2.168623e-14        0.452060
# Day                      NaN  NaN           NaN             NaN
# Year            2.168623e-14  NaN  1.000000e+00        0.033659
# AvgTemperature  4.520600e-01  NaN  3.365939e-02        1.000000

# %%
_= sns.heatmap(c)

# %% [markdown]
# ## Bad Data

# %% [markdown]
# Now we will take a look at some data with problematic values in it. To do that, we read a new csv file with temperatures from across the world, called `temperature.csv`

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

import os
os.chdir("/content/drive/My Drive/AIMOOC")

import pandas as pd
df2 = pd.read_csv("/content/drive/My Drive/AIMOOC/Modules/Module1/Data/city_temperature.csv")
df2
# Out:
# Mounted at /content/drive/
# <ipython-input-185-3ba8c263cb4f>:8: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("/content/drive/My Drive/AIMOOC/Modules/Module1/Data/city_temperature.csv")
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
#          Month  Day  Year  AvgTemperature
# 0            1    1  1995            64.2
# 1            1    2  1995            49.4
# 2            1    3  1995            48.8
# 3            1    4  1995            46.4
# 4            1    5  1995            47.9
# ...        ...  ...   ...             ...
# 2906322      7   27  2013            82.4
# 2906323      7   28  2013            81.6
# 2906324      7   29  2013            84.2
# 2906325      7   30  2013            83.8
# 2906326      7   31  2013            83.6
#
# [2906327 rows x 8 columns]

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
df2 = pd.read_csv("/content/drive/My Drive/AIMOOC/Modules/Module1/Data/city_temperature.csv")
df2
# Out:
# <ipython-input-186-138a25ade691>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("/content/drive/My Drive/AIMOOC/Modules/Module1/Data/city_temperature.csv")
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
#          Month  Day  Year  AvgTemperature
# 0            1    1  1995            64.2
# 1            1    2  1995            49.4
# 2            1    3  1995            48.8
# 3            1    4  1995            46.4
# 4            1    5  1995            47.9
# ...        ...  ...   ...             ...
# 2906322      7   27  2013            82.4
# 2906323      7   28  2013            81.6
# 2906324      7   29  2013            84.2
# 2906325      7   30  2013            83.8
# 2906326      7   31  2013            83.6
#
# [2906327 rows x 8 columns]

# %% [markdown]
# ### Missing Data

# %%
na_vals = df2.isna() 
na_vals
# Out:
#          Region  Country  State   City  Month    Day   Year  AvgTemperature
# 0         False    False   True  False  False  False  False           False
# 1         False    False   True  False  False  False  False           False
# 2         False    False   True  False  False  False  False           False
# 3         False    False   True  False  False  False  False           False
# 4         False    False   True  False  False  False  False           False
# ...         ...      ...    ...    ...    ...    ...    ...             ...
# 2906322   False    False  False  False  False  False  False           False
# 2906323   False    False  False  False  False  False  False           False
# 2906324   False    False  False  False  False  False  False           False
# 2906325   False    False  False  False  False  False  False           False
# 2906326   False    False  False  False  False  False  False           False
#
# [2906327 rows x 8 columns]

# %%
na_cols = na_vals.any()  
na_cols
# Out:
# Region            False
# Country           False
# State              True
# City              False
# Month             False
# Day               False
# Year              False
# AvgTemperature    False
# dtype: bool

# %%
df2.columns[na_cols].to_list()
# Out:
# ['State']

# %%
df2 = df2.dropna()  
df2
# Out:
#                 Region Country                   State                  City  \
# 1450990  North America      US                 Alabama            Birmingham
# 1450991  North America      US                 Alabama            Birmingham
# 1450992  North America      US                 Alabama            Birmingham
# 1450993  North America      US                 Alabama            Birmingham
# 1450994  North America      US                 Alabama            Birmingham
# ...                ...     ...                     ...                   ...
# 2906322  North America      US  Additional Territories  San Juan Puerto Rico
# 2906323  North America      US  Additional Territories  San Juan Puerto Rico
# 2906324  North America      US  Additional Territories  San Juan Puerto Rico
# 2906325  North America      US  Additional Territories  San Juan Puerto Rico
# 2906326  North America      US  Additional Territories  San Juan Puerto Rico
#
#          Month  Day  Year  AvgTemperature
# 1450990      1    1  1995            50.7
# 1450991      1    2  1995            37.2
# 1450992      1    3  1995            33.2
# 1450993      1    4  1995            33.3
# 1450994      1    5  1995            26.4
# ...        ...  ...   ...             ...
# 2906322      7   27  2013            82.4
# 2906323      7   28  2013            81.6
# 2906324      7   29  2013            84.2
# 2906325      7   30  2013            83.8
# 2906326      7   31  2013            83.6
#
# [1455337 rows x 8 columns]

# %%
df2.groupby("Country").min()
# Out:
#                 Region                   State     City  Month  Day  Year  \
# Country
# US       North America  Additional Territories  Abilene      1    1  1995
#
#          AvgTemperature
# Country
# US                -99.0

# %% [markdown]
# ### Incorrect Data

# %%
df2.loc[df2["AvgTemperature"] == -99]
# Out:
#                 Region Country                   State                  City  \
# 1451059  North America      US                 Alabama            Birmingham
# 1451061  North America      US                 Alabama            Birmingham
# 1452443  North America      US                 Alabama            Birmingham
# 1452449  North America      US                 Alabama            Birmingham
# 1452450  North America      US                 Alabama            Birmingham
# ...                ...     ...                     ...                   ...
# 2905471  North America      US  Additional Territories  San Juan Puerto Rico
# 2905534  North America      US  Additional Territories  San Juan Puerto Rico
# 2905689  North America      US  Additional Territories  San Juan Puerto Rico
# 2905726  North America      US  Additional Territories  San Juan Puerto Rico
# 2905749  North America      US  Additional Territories  San Juan Puerto Rico
#
#          Month  Day  Year  AvgTemperature
# 1451059      3   11  1995           -99.0
# 1451061      3   13  1995           -99.0
# 1452443     12   24  1998           -99.0
# 1452449     12   30  1998           -99.0
# 1452450     12   31  1998           -99.0
# ...        ...  ...   ...             ...
# 2905471      3   29  2011           -99.0
# 2905534      5   31  2011           -99.0
# 2905689     11    2  2011           -99.0
# 2905726     12    9  2011           -99.0
# 2905749      1    1  2012           -99.0
#
# [4782 rows x 8 columns]
